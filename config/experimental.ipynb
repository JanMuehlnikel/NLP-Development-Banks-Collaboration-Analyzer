# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../src/merged_orgas.csv")

df.head(2)
# Out:
#           iati_id iati_orga_id orga_abbreviation  \
# 0  DE-1-199535469         DE-1               bmz
# 1  DE-1-199665852         DE-1               bmz
#
#                                       orga_full_name  \
# 0  Bundesministerium für wirtschaftliche Zusammen...
# 1  Bundesministerium für wirtschaftliche Zusammen...
#
#                      title_en                     title_other  \
# 0    Studies and Experts Fund    Studien- und Fachkräftefonds
# 1  Windhoek Water Reclamation  Abwasserrückgewinnung Windhoek
#
#                    title_main  \
# 0    Studies and Experts Fund
# 1  Windhoek Water Reclamation
#
#                                         organization country_code country  \
# 0  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
# 1  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
#
#    ...         planned_start          actual_start           planned_end  \
# ...

# %%
sdg_df = pd.read_csv("../../src/merged_orgas_sdg.csv")

sdg_df.head(2)
# Out:
#           iati_id                    title_en                     title_other  \
# 0  DE-1-199535469    Studies and Experts Fund    Studien- und Fachkräftefonds
# 1  DE-1-199665852  Windhoek Water Reclamation  Abwasserrückgewinnung Windhoek
#
#                    title_main  \
# 0    Studies and Experts Fund
# 1  Windhoek Water Reclamation
#
#                                         organization country_code country  \
# 0  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
# 1  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
#
#   region      location                                     description_en  \
# 0    NaN  ['Windhoek']  Preparation and appraisal of technical coopera...
# 1    NaN  ['Windhoek']  Windhoek Water Reclamation; Windhoek Water Rec...
#
#    ...           planned_end            actual_end           last_update  \
# 0  ...  2026-12-31T00:00:00Z  2024-01-31T00:00:00Z  2024-01-31T00:00:00Z
# ...

# %%
nan_in_a = sdg_df[sdg_df['sgd_pred_code'].isna()]

len(nan_in_a)
# Out:
# 0

# %%
sdg_df['sgd_pred_code'].value_counts()
# Out:
# sgd_pred_code
# 10    8382
# 3     7263
# 14    5296
# 9     4804
# 8     4343
# 12    4029
# 11    4018
# 15    3984
# 1     2976
# 13    2901
# 5     2437
# 7     2156
# 4      506
# 2      465
# 6      337
# Name: count, dtype: int64

# %%
new_df = df.merge(sdg_df[['iati_id', 'sgd_pred_code']], how='inner', on='iati_id')

# %%
new_df.head(2)
# Out:
#           iati_id iati_orga_id orga_abbreviation  \
# 0  DE-1-199535469         DE-1               bmz
# 1  DE-1-199535469         DE-1               bmz
#
#                                       orga_full_name  \
# 0  Bundesministerium für wirtschaftliche Zusammen...
# 1  Bundesministerium für wirtschaftliche Zusammen...
#
#                    title_en                   title_other  \
# 0  Studies and Experts Fund  Studien- und Fachkräftefonds
# 1  Studies and Experts Fund  Studien- und Fachkräftefonds
#
#                  title_main  \
# 0  Studies and Experts Fund
# 1  Studies and Experts Fund
#
#                                         organization country_code country  \
# 0  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
# 1  Bundesministerium für wirtschaftliche Zusammen...       ['NA']    NA;
#
#    ...          actual_start           planned_end            actual_end  \
# 0  ...  2024-01-01T00:00:00Z  2026-12-31T00:00:00Z  2024-01-31T00:00:00Z
# ...

# %%
len(new_df)
# Out:
# 54795

# %%
new_df.to_csv("../../src/merged_orgas.csv", index=False)
