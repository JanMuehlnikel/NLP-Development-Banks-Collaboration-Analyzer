# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../src/merged_orgas.csv")
df.head()
# Out:
# C:\Users\UserNA6153\AppData\Local\Temp\ipykernel_25108\453729359.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../src/merged_orgas.csv")
#           iati_id iati_orga_id orga_abbreviation  \
# 0  DE-1-199535469         DE-1               bmz
# 1  DE-1-199665852         DE-1               bmz
# 2  DE-1-199870015         DE-1               bmz
# 3  DE-1-200070003         DE-1               bmz
# 4  DE-1-200166116         DE-1               bmz
#
#                                       orga_full_name project_number  \
# 0  Bundesministerium für wirtschaftliche Zusammen...              1
# 1  Bundesministerium für wirtschaftliche Zusammen...              1
# 2  Bundesministerium für wirtschaftliche Zusammen...              1
# 3  Bundesministerium für wirtschaftliche Zusammen...              1
# 4  Bundesministerium für wirtschaftliche Zusammen...              1
#
# ...
