# %% [markdown]
# ## **Dependencies**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load Data**

# %%
df = pd.read_csv("../../src/merged_orgas.csv")
df.head(1)
# Out:
# C:\Users\UserNA6153\AppData\Local\Temp\ipykernel_11888\34694008.py:1: DtypeWarning: Columns (11,18,20,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../src/merged_orgas.csv")
#             iati_id iati_orga_id orga_abbreviation  \
# 0  DE-1-201401124-0         DE-1               bmz
#
#                                       orga_full_name client  \
# 0  Bundesministerium für wirtschaftliche Zusammen...    BMZ
#
#                                             title_en  \
# 0  Kenia Protected Relief and Recovery Programme ...
#
#                                          title_other  \
# 0  Kenia Protected Relief and Recovery Programme ...
#
#                                           title_main  \
# 0  Kenia Protected Relief and Recovery Programme ...
#
#                                         organization country_code  ...  \
# 0  Bundesministerium für wirtschaftliche Zusammen...       ['KE']  ...
#
# ...

# %%
df.columns
# Out:
# Index(['iati_id', 'iati_orga_id', 'orga_abbreviation', 'orga_full_name',
#        'client', 'title_en', 'title_other', 'title_main', 'organization',
#        'country_code', 'country', 'region', 'location', 'description_en',
#        'description_other', 'description_main', 'status', 'planned_start',
#        'actual_start', 'planned_end', 'actual_end', 'last_update',
#        'crs_5_code', 'crs_5_name', 'crs_3_code', 'crs_3_name', 'docs',
#        'title_and_description', 'sgd_pred_code', 'sgd_pred_str'],
#       dtype='object')

# %% [markdown]
# ## **Descriptions**

# %%
df[df["orga_abbreviation"] == "aa"]
# Out:
#                   iati_id iati_orga_id orga_abbreviation   orga_full_name  \
# 30028  XM-DAC-5-7-6618630   XM-DAC-5-7                aa  Auswärtiges Amt
# 30029  XM-DAC-5-7-6618432   XM-DAC-5-7                aa  Auswärtiges Amt
# 30030  XM-DAC-5-7-6618435   XM-DAC-5-7                aa  Auswärtiges Amt
# 30031  XM-DAC-5-7-6618301   XM-DAC-5-7                aa  Auswärtiges Amt
# 30032  XM-DAC-5-7-6618318   XM-DAC-5-7                aa  Auswärtiges Amt
# ...                   ...          ...               ...              ...
# 32771  XM-DAC-5-7-6611239   XM-DAC-5-7                aa  Auswärtiges Amt
# 32772  XM-DAC-5-7-6611282   XM-DAC-5-7                aa  Auswärtiges Amt
# 32773  XM-DAC-5-7-6611302   XM-DAC-5-7                aa  Auswärtiges Amt
# 32774  XM-DAC-5-7-6611428   XM-DAC-5-7                aa  Auswärtiges Amt
# 32775  XM-DAC-5-7-6610650   XM-DAC-5-7                aa  Auswärtiges Amt
#
#       client title_en title_other title_main organization country_code  ...  \
# ...
