# %% [markdown]
# # **Merge all organizational csv files to one**

# %% [markdown]
# ## **Dependencies**

# %%
import pandas as pd

# Your current dirctory has to be /data/pipeline/notebooks to not get FileNotFoundError
from importlib.machinery import SourceFileLoader
CONSTANTS = SourceFileLoader("CONSTANTS", "../../../config/CONSTANTS.py").load_module()

# %% [markdown]
# ## **Merge**

# %%
combined_df = pd.DataFrame()

for key, values in CONSTANTS.ORGANIZATIONS.items():
    path = f"../../../src/transformed/transformed_{values[1]}.csv"

    temp_df = pd.read_csv(path)
    combined_df = pd.concat([combined_df, temp_df], ignore_index=True)

combined_df.to_csv("../../../src/merged_orgas.csv", index=False)

# %%
combined_df.head()
# Out:
#             iati_id                                           title_en  \
# 0    DE-1-201044809                                 Integrated Experts
# 1  DE-1-201416684-0  ABC Project -  Alphabetize students, Books for...
# 2    DE-1-201424720  Information on geo-resources with a focus on s...
# 3  DE-1-201073626-0  Grants for development oriented Master and doc...
# 4  DE-1-201430198-0  Strengthening civil society and capacity to mo...
#
#                                          title_other  \
# 0                Zuschüsse an integrierte Fachkräfte
# 1  ABC Projekt - Alphabetisierung für Schüler, Bi...
# 2  Informationen zu Georessourcen mit dem Schwerp...
# 3  Vergabe von Stipendien für entwicklungsbezogen...
# 4  Stärkung lokaler Bürgerinitiativen in ihrem En...
#
#                                           title_main  \
# 0                                 Integrated Experts
# 1  ABC Project -  Alphabetize students, Books for...
# 2  Information on geo-resources with a focus on s...
# 3  Grants for development oriented Master and doc...
# 4  Strengthening civil society and capacity to mo...
#
#                                         organization country   region  \
# 0  Bundesministerium für wirtschaftliche Zusammen...     NaN  ['998']
# 1  Bundesministerium für wirtschaftliche Zusammen...  ['CM']      NaN
# 2  Bundesministerium für wirtschaftliche Zusammen...  ['CM']      NaN
# 3  Bundesministerium für wirtschaftliche Zusammen...     NaN  ['998']
# 4  Bundesministerium für wirtschaftliche Zusammen...  ['CM']      NaN
#
#       location                                     description_en  \
# 0          NaN  Dismantling professional force lack; Dismantli...
# 1  ['Yaounde']  ABC Project -  Alphabetize students, Books for...
# 2  ['Yaounde']  The project supports spatial planning decision...
# 3          NaN  Grants for development oriented Master and doc...
# 4  ['Yaounde']  Strengthening civil society and capacity to mo...
#
#                                    description_other  ...  \
# 0     Abbau Fachkräftemangel; Abbau Fachkräftemangel  ...
# 1  ABC Projekt - Alphabetisierung für Schüler, Bi...  ...
# 2  Das Vorhaben unterstützt die Entscheidungsträg...  ...
# 3  Vergabe von Stipendien für entwicklungsbezogen...  ...
# 4  Stärkung lokaler Bürgerinitiativen in ihrem En...  ...
#
#           planned_start          actual_start           planned_end  \
# 0  2017-12-06T00:00:00Z  2017-12-06T00:00:00Z  2024-12-31T00:00:00Z
# 1  2017-12-06T00:00:00Z  2017-12-06T00:00:00Z  2024-12-31T00:00:00Z
# 2  2017-12-06T00:00:00Z  2017-12-06T00:00:00Z  2024-12-31T00:00:00Z
# 3  2017-12-06T00:00:00Z  2017-12-06T00:00:00Z  2024-12-31T00:00:00Z
# 4  2017-12-06T00:00:00Z  2017-12-06T00:00:00Z  2024-12-31T00:00:00Z
#
#              actual_end           last_update             crs_5_code  \
# 0  2023-06-30T00:00:00Z  2023-12-31T00:00:00Z                43010;
# 1  2023-06-30T00:00:00Z  2024-01-22T00:00:00Z                11220;
# 2  2023-06-30T00:00:00Z  2023-12-31T00:00:00Z  41010; 41082; 43040;
# 3  2023-06-30T00:00:00Z  2024-01-22T00:00:00Z                43081;
# 4  2023-06-30T00:00:00Z  2024-01-22T00:00:00Z                15160;
#
#                                           crs_5_name       crs_3_code  \
# 0                                  Multisector aid;             430;
# 1                                Primary education;             112;
# 2  Environmental policy and administrative manage...  410; 410; 430;
# 3                   Multisector education/training;             430;
# 4                                     Human rights;             151;
#
#                                           crs_3_name  \
# 0                                Other Multisector;
# 1                                  Basic Education;
# 2  General Environment Protection; General Enviro...
# 3                                Other Multisector;
# 4               Government & Civil Society-general;
#
#                                                 docs
# 0  ['https://www.giz.de/projektdaten/projects.act...
# 1  ['https://www.bmz.de/de/laender/kamerun', 'htt...
# 2  ['https://www.bgr.bund.de/EN/Themen/Zusammenar...
# 3                                                NaN
# 4  ['https://www.bmz.de/de/laender/kamerun', 'htt...
#
# [5 rows x 22 columns]
