# %% [markdown]
# # **Merge all organizational csv files to one**

# %% [markdown]
# ## **Dependencies**

# %%
import pandas as pd

# Your current dirctory has to be /data/pipeline/notebooks to not get FileNotFoundError
from importlib.machinery import SourceFileLoader
CONSTANTS = SourceFileLoader("CONSTANTS", "../../../config/CONSTANTS.py").load_module()

# %% [markdown]
# ## **Merge**

# %%
combined_df = pd.DataFrame()

for key, values in CONSTANTS.ORGANIZATIONS.items():
    path = f"../../../src/transformed/transformed_{values[1]}.csv"

    temp_df = pd.read_csv(path)
    combined_df = pd.concat([combined_df, temp_df], ignore_index=True)

combined_df.to_csv("../../../src/merged_orgas.csv", index=False)

# %%
combined_df.head()
# Out:
#             iati_id                                           title_en  \
# 0  DE-1-201629492-0  Basic health services with focus on reducing m...
# 1  DE-1-201673854-0  Sustainable Water Sources and Livelihoods amon...
# 2  DE-1-201676782-0  Practical Vocational Skills Training with Pers...
# 3  DE-1-201676790-0           Community Empowerment and Peace Building
# 4  DE-1-201676808-0  Training Quality Teachers for the development ...
#
#                                          title_other  \
# 0  Basisgesundheitsdienste zur Senkung der Mütter...
# 1   Nachhaltige Wasserversorgung und Lebensunterhalt
# 2  Wirtschaftliche Selbständigkeit junger Frauen ...
# 3  Stärkung des Gemeindelebens und Friedensbildun...
# 4  Primarschullehrerausbildung Südsudan, Fortführung
#
#                                         organization country region  location  \
# 0  Bundesministerium für wirtschaftliche Zusammen...  ['SS']    NaN  ['Juba']
# 1  Bundesministerium für wirtschaftliche Zusammen...  ['SS']    NaN  ['Juba']
# 2  Bundesministerium für wirtschaftliche Zusammen...  ['SS']    NaN  ['Juba']
# 3  Bundesministerium für wirtschaftliche Zusammen...  ['SS']    NaN  ['Juba']
# 4  Bundesministerium für wirtschaftliche Zusammen...  ['SS']    NaN  ['Juba']
#
#                                       description_en  \
# 0  Basic health services with focus on reducing m...
# 1  Sustainable Water Sources and Livelihoods amon...
# 2  Practical Vocational Skills Training with Pers...
# 3  Community Empowerment and Peace Building; This...
# 4  Training Quality Teachers for the development ...
#
#                                    description_other        status  \
# 0  Basisgesundheitsdienste zur Senkung der Mütter...  Finalisation
# 1  Nachhaltige Wasserversorgung und Lebensunterha...  Finalisation
# 2  Wirtschaftliche Selbständigkeit junger Frauen ...  Finalisation
# 3  Stärkung des Gemeindelebens und Friedensbildun...  Finalisation
# 4  Primarschullehrerausbildung Südsudan, Fortführ...  Finalisation
#
#           planned_start          actual_start           planned_end  \
# 0  2016-06-14T00:00:00Z  2016-06-14T00:00:00Z  2016-12-31T00:00:00Z
# 1  2016-06-14T00:00:00Z  2016-06-14T00:00:00Z  2016-12-31T00:00:00Z
# 2  2016-06-14T00:00:00Z  2016-06-14T00:00:00Z  2016-12-31T00:00:00Z
# 3  2016-06-14T00:00:00Z  2016-06-14T00:00:00Z  2016-12-31T00:00:00Z
# 4  2016-06-14T00:00:00Z  2016-06-14T00:00:00Z  2016-12-31T00:00:00Z
#
#              actual_end           last_update crs_5_code  \
# 0  2016-12-31T00:00:00Z  2024-01-22T00:00:00Z    12230;
# 1  2016-12-31T00:00:00Z  2024-01-22T00:00:00Z    43040;
# 2  2016-12-31T00:00:00Z  2024-01-22T00:00:00Z    11330;
# 3  2016-12-31T00:00:00Z  2024-01-22T00:00:00Z    15220;
# 4  2016-12-31T00:00:00Z  2024-01-22T00:00:00Z    11130;
#
#                                           crs_5_name crs_3_code  \
# 0                      Basic health infrastructure;       122;
# 1                                Rural development;       430;
# 2                              Vocational training;       113;
# 3  Civilian peace-building, conflict prevention a...      152;
# 4                                 Teacher training;       111;
#
#                        crs_3_name  \
# 0                  Basic Health;
# 1             Other Multisector;
# 2           Secondary Education;
# 3    Conflict, Peace & Security;
# 4  Education, Level Unspecified;
#
#                                                 docs
# 0  ['https://www.bmz.de/de/laender/suedsudan', 'h...
# 1  ['https://www.bmz.de/de/laender/suedsudan', 'h...
# 2  ['https://www.bmz.de/de/laender/suedsudan', 'h...
# 3  ['https://www.bmz.de/de/laender/suedsudan', 'h...
# 4  ['https://www.bmz.de/de/laender/suedsudan', 'h...
