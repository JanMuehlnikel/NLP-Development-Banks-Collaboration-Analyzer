# %% [markdown]
# # **CRS Overlap**

# %% [markdown]
# ## **Dependencies**

# %%
import pandas as pd

# %% [markdown]
# ## **Config**

# %%
df = pd.read_csv("../src/merged_orgas.csv")

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Auto-detect the display width
pd.set_option('display.max_colwidth', None)  # Show full content of each column

df.head(1)
# Out:
#             iati_id  \
# 0  DE-1-201629492-0
#
#                                                                                                                 title_en  \
# 0  Basic health services with focus on reducing maternal and child morbidity and mortality in Torit Diocese, South Sudan
#
#                                                                                                   title_other  \
# 0  Basisgesundheitsdienste zur Senkung der Mütter-und Kindersterblichkeit in sechs Regionen der Diözese Torit
#
#                                                                  organization  \
# 0  Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
#
#   country region  location  \
# 0  ['SS']    NaN  ['Juba']
#
# ...

# %% [markdown]
# ## **CRS3 Overlap**

# %%
filtered_df = df[df["crs_3_code"].str.contains('313', na=False)]

filtered_df[["organization", "title_en", "title_other", "description_en", "description_other", "country", "region", "crs_3_code", "crs_3_name"]]
# Out:
#                                                                      organization  \
# 314    Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 1477   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 1908   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 2727   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 2782   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 3140   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 3437   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 3901   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 4578   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# 5428   Bundesministerium für wirtschaftliche Zusammenarbeit und Entwicklung (BMZ)
# ...
